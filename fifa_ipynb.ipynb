# %% [markdown]
# These are the question I have analysed in given data set:
# 1. How many category present in dataset.And how many teams are present inside each category.
# 2. Which country from team1 played against which country from team2 per category.
# 3. Match played by which countries on which date.
# 4. How many goals done by team 1 per country.
# 5. How many goals done by team 2 per country
# 6. which countries participated in FIFA match
# 7. How many match played by each country for team 1 and team 2.
# 8. How many yellow card team have in total attempts per category for team 1
# 9. How many yellow card team have in total attempts per category for team 2
# 10. Category wise analysis:-
#     Group A(Analysed only one group out of 8):-
#         1. Goal done by team1 and team 2
#         2. How many yellow card team 1 & 2 have
#         3. Channel count for team 1 and team2 both left and right channel
#         4. Goal prevention by team 1
#         5. Goal prevetion by team2
#
#     quarter-final:-
#         1. How many teams participated in quarter-final. Match played between which country on which date.
#         2. No of goals for team 1 per attempts
#         3. No of goals for team2 per attempts
#         4. Relation between number of goals team' , 'total attempts team' , 'goal inside the penalty area team' , 'goal outside the penalty area team' , 'on target attempts team' ,'off target attempts team' , 'fouls against team' , 'offsides team' for team1 and team2
#         5. Goal inside penalty area count percentage for both team
#         6. Goal outside penalty area count percentage for both team
#
#     Semi-Final:-
#         1. Country wise no of goals vs attempts
#
#     Final:
#         1. Team Name, Counts
# 11. Corrleation between these values of team 1 and team 2
#     number of goals team1' , 'total attempts team1' , 'goal inside the penalty area team1' , 'goal outside the penalty area team1' , 'on target attempts team1' ,'off target attempts team1' , 'fouls against team1' , 'offsides team1'
# 12. Relation between no of goal, total attemps, goal inside penalty area and goal outside penalty area
# 13. which teams are highest Performing per category played on which date
# 14. which teams are lowest Performing per category played on which date
# 15. Analyse possession in contest for whole match
# 16. Which Country from team1 played again which Country from team2 on which Date
# 17. Which Match played maximun duration
# 18. Which Match played minimun duration

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("G:\Learning\Teaching\Datahour_Webinar\Fifa_world_cup_matches.csv")

# %%
pd.set_option("display.max_columns", 200)
pd.set_option("display.max_rows", 200)
pd.set_option("display.width", 1000)

# %%
df.head(2)
# Out:
#      team1    team2 possession team1 possession team2 possession in contest  number of goals team1  number of goals team2         date     hour category  total attempts team1  total attempts team2  conceded team1  conceded team2  goal inside the penalty area team1  goal inside the penalty area team2  goal outside the penalty area team1  goal outside the penalty area team2  assists team1  assists team2  on target attempts team1  on target attempts team2  off target attempts team1  off target attempts team2  attempts inside the penalty area team1  attempts inside the penalty area  team2  attempts outside the penalty area  team1  attempts outside the penalty area  team2  left channel team1  left channel team2  left inside channel team1  left inside channel team2  central channel team1  central channel team2  right inside channel team1  right inside channel team2  right channel team1  right channel team2  total offers to receive team1  total offers to receive team2  \
# ...

# %%
df.shape
# Out:
# (64, 88)

# %%
df.columns
# Out:
# Index(['team1', 'team2', 'possession team1', 'possession team2', 'possession in contest', 'number of goals team1', 'number of goals team2', 'date', 'hour', 'category', 'total attempts team1', 'total attempts team2', 'conceded team1', 'conceded team2', 'goal inside the penalty area team1', 'goal inside the penalty area team2', 'goal outside the penalty area team1', 'goal outside the penalty area team2', 'assists team1', 'assists team2', 'on target attempts team1', 'on target attempts team2', 'off target attempts team1', 'off target attempts team2', 'attempts inside the penalty area team1', 'attempts inside the penalty area  team2', 'attempts outside the penalty area  team1', 'attempts outside the penalty area  team2', 'left channel team1', 'left channel team2', 'left inside channel team1', 'left inside channel team2', 'central channel team1', 'central channel team2', 'right inside channel team1', 'right inside channel team2', 'right channel team1', 'right channel team2',
# ...

# %%
df.describe()
# Out:
#        number of goals team1  number of goals team2  total attempts team1  total attempts team2  conceded team1  conceded team2  goal inside the penalty area team1  goal inside the penalty area team2  goal outside the penalty area team1  goal outside the penalty area team2  assists team1  assists team2  on target attempts team1  on target attempts team2  off target attempts team1  off target attempts team2  attempts inside the penalty area team1  attempts inside the penalty area  team2  attempts outside the penalty area  team1  attempts outside the penalty area  team2  left channel team1  left channel team2  left inside channel team1  left inside channel team2  central channel team1  central channel team2  right inside channel team1  right inside channel team2  right channel team1  right channel team2  total offers to receive team1  total offers to receive team2  inbehind offers to receive team1  inbehind offers to receive team2  inbetween offers to receive team1  \
# ...

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 88 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   team1                                                  64 non-null     object
#  1   team2                                                  64 non-null     object
#  2   possession team1                                       64 non-null     object
#  3   possession team2                                       64 non-null     object
#  4   possession in contest                                  64 non-null     object
#  5   number of goals team1                                  64 non-null     int64
#  6   number of goals team2                                  64 non-null     int64
#  7   date                                                   64 non-null     object
# ...

# %% [markdown]
# Data Cleaning:-
# 1. Converting Data Type
# 2. Inspecting Missing Values
# 3. Removing Duplicates
# 4. Remove unwanted colums

# %% [markdown]
# Data type conversion

# %%
#Changing date datatype from object to date
df['date'] = pd.to_datetime(df['date'])

# %%
df.select_dtypes(include=['object'])
# Out:
#              team1           team2 possession team1 possession team2 possession in contest     hour                  category
# 0            QATAR         ECUADOR              42%              50%                    8%  17 : 00                   Group A
# 1          ENGLAND            IRAN              72%              19%                    9%  14 : 00                   Group B
# 2          SENEGAL     NETHERLANDS              44%              45%                   11%  17 : 00                   Group A
# 3    UNITED STATES           WALES              51%              39%                   10%  20 : 00                   Group B
# 4        ARGENTINA    SAUDI ARABIA              64%              24%                   12%  11 : 00                   Group C
# 5          DENMARK         TUNISIA              55%              33%                   12%  14 : 00                   Group D
# ...

# %%
df.dtypes
# Out:
# team1                                                            object
# team2                                                            object
# possession team1                                                 object
# possession team2                                                 object
# possession in contest                                            object
# number of goals team1                                             int64
# number of goals team2                                             int64
# date                                                     datetime64[ns]
# hour                                                             object
# category                                                         object
# total attempts team1                                              int64
# total attempts team2                                              int64
# conceded team1                                                    int64
# ...

# %%
#Changing Datatypes from object to str
df = df.astype({"team1": "string", "team2": "string","category":"string"})
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 88 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   team1                                                  64 non-null     string
#  1   team2                                                  64 non-null     string
#  2   possession team1                                       64 non-null     object
#  3   possession team2                                       64 non-null     object
#  4   possession in contest                                  64 non-null     object
#  5   number of goals team1                                  64 non-null     int64
#  6   number of goals team2                                  64 non-null     int64
#  7   date                                                   64 non-null     datetime64[ns]
# ...

# %%
df['possession team1'] = df['possession team1'].str.replace('%','').astype(int)
df['possession team2'] = df['possession team2'].str.replace('%','').astype(int)

# %% [markdown]
# Integer data type take up less space than string, hence data type conversion is important.

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 88 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   team1                                                  64 non-null     string
#  1   team2                                                  64 non-null     string
#  2   possession team1                                       64 non-null     int32
#  3   possession team2                                       64 non-null     int32
#  4   possession in contest                                  64 non-null     object
#  5   number of goals team1                                  64 non-null     int64
#  6   number of goals team2                                  64 non-null     int64
#  7   date                                                   64 non-null     datetime64[ns]
# ...

# %% [markdown]
# Inspecting missing values in datasets

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# team1                                                    0
# team2                                                    0
# passes team1                                             0
# offsides team2                                           0
# offsides team1                                           0
# fouls against team2                                      0
# fouls against team1                                      0
# red cards team2                                          0
# red cards team1                                          0
# yellow cards team2                                       0
# yellow cards team1                                       0
# completed defensive line breaks team2                    0
# completed defensive line breaksteam1                     0
# attempted defensive line breaks team2                    0
# attempted defensive line breaks team1                    0
# completed line breaks team2                              0
# ...

# %%
#No Null value
round(df.isnull().sum()/df.shape[0]*100,2).sort_values(ascending=False)
# Out:
# team1                                                    0.0
# team2                                                    0.0
# passes team1                                             0.0
# offsides team2                                           0.0
# offsides team1                                           0.0
# fouls against team2                                      0.0
# fouls against team1                                      0.0
# red cards team2                                          0.0
# red cards team1                                          0.0
# yellow cards team2                                       0.0
# yellow cards team1                                       0.0
# completed defensive line breaks team2                    0.0
# completed defensive line breaksteam1                     0.0
# attempted defensive line breaks team2                    0.0
# attempted defensive line breaks team1                    0.0
# ...

# %% [markdown]
# There are 2 Methos to handle missing values:-
# 1. Deletion
# 2. Imputation(Replacing value with constant, mean, median, mode etc.)
#
# As per above result, we don't have any missing values.

# %% [markdown]
# Remove Duplicate Rows

# %%
# df.shape
df.drop_duplicates()
df.shape
# Out:
# (64, 88)

# %% [markdown]
# Remove unwanted column to reduce complexity and enhance analysis

# %%
# df.drop(columns=['possession in contest','hour','conceded team1','conceded team2','assists team1','assists team2','receptions between midfield and defensive lines team1','receptions between midfield and defensive lines team2'], inplace=True)
# df.shape
df.drop(columns=['own goals team1','own goals team2','crosses team1','crosses team2','crosses completed team1','crosses completed team2'], inplace=True)
df.shape
# Out:
# (64, 82)

# %% [markdown]
# Analysis:-

# %%
plt.figure(figsize=[20,5])

sns.barplot(x=df.category.value_counts().index, 
            y=df.category.value_counts().values).set_title("TEAM COUNTS PER GROUP", 
                                                                          fontsize=30, color='Green', pad = 20)

plt.xlabel('GROUP TYPE', fontsize= 20, color='Brown')
plt.xticks(rotation=45)

plt.show()

# %%
pd.unique(df[['team1', 'team2']].values.ravel('K'))
# Out:
# array(['QATAR', 'ENGLAND', 'SENEGAL', 'UNITED STATES', 'ARGENTINA',
#        'DENMARK', 'MEXICO', 'FRANCE', 'MOROCCO', 'GERMANY', 'SPAIN',
#        'BELGIUM', 'SWITZERLAND', 'URUGUAY', 'PORTUGAL', 'BRAZIL', 'WALES',
#        'NETHERLANDS', 'TUNISIA', 'POLAND', 'JAPAN', 'CROATIA', 'CAMEROON',
#        'KOREA REPUBLIC', 'ECUADOR', 'IRAN', 'AUSTRALIA', 'SAUDI ARABIA',
#        'CANADA', 'COSTA RICA', 'GHANA', 'SERBIA'], dtype=object)

# %% [markdown]
# Analysis:- Above Countries participated in FIFA Match

# %% [markdown]
# Univariate Analysis:- In above plot, used one variable for analysis. These are 13 category and analaysed how many teams are present per category.

# %%
sns.lineplot(x="team1",y="team2",data=df,c = 'Green',linewidth = '2',hue='category')
plt.xticks(rotation = 90)
f = plt.figure()
f.set_figwidth(15)
f.set_figheight(10)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Bivariate Analysis:- Above plot shows which country from team1 played match against which country per catergory. Above plot is bivariate becuase we have used 2 variable for analysis.

# %%
sns.lineplot(x="team1",y="team2",data=df,c = 'Green',linewidth = '2',hue='date')
plt.xticks(rotation = 90)
f = plt.figure()
f.set_figwidth(15)
f.set_figheight(15)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Analysis:- Above plot shows which country played against which country on which date

# %% [markdown]
# Analysing Team 1 Info

# %%
team1=[x for x in df.columns if "team1" in x]
team1
# Out:
# ['team1',
#  'possession team1',
#  'number of goals team1',
#  'total attempts team1',
#  'conceded team1',
#  'goal inside the penalty area team1',
#  'goal outside the penalty area team1',
#  'assists team1',
#  'on target attempts team1',
#  'off target attempts team1',
#  'attempts inside the penalty area team1',
#  'attempts outside the penalty area  team1',
#  'left channel team1',
#  'left inside channel team1',
#  'central channel team1',
#  'right inside channel team1',
#  'right channel team1',
#  'total offers to receive team1',
#  'inbehind offers to receive team1',
#  'inbetween offers to receive team1',
#  'infront offers to receive team1',
#  'receptions between midfield and defensive lines team1',
#  'attempted line breaks team1',
#  'completed line breaksteam1',
#  'attempted defensive line breaks team1',
#  'completed defensive line breaksteam1',
#  'yellow cards team1',
#  'red cards team1',
#  'fouls against team1',
#  'offsides team1',
#  'passes team1',
# ...

# %%
team1_df = df[team1].copy()
team1_df
# Out:
#              team1  possession team1  number of goals team1  total attempts team1  conceded team1  goal inside the penalty area team1  goal outside the penalty area team1  assists team1  on target attempts team1  off target attempts team1  attempts inside the penalty area team1  attempts outside the penalty area  team1  left channel team1  left inside channel team1  central channel team1  right inside channel team1  right channel team1  total offers to receive team1  inbehind offers to receive team1  inbetween offers to receive team1  infront offers to receive team1  receptions between midfield and defensive lines team1  attempted line breaks team1  completed line breaksteam1  attempted defensive line breaks team1  completed defensive line breaksteam1  yellow cards team1  red cards team1  fouls against team1  offsides team1  passes team1  passes completed team1  switches of play completed team1  corners team1  free kicks team1  penalties scored team1  goal preventions team1  \
# ...

# %%
plt.figure(figsize=[10,5])
sns.barplot(x=team1_df["team1"], y=team1_df["number of goals team1"]).set_title("Number Of Goals By Team1", fontsize=20, color='Blue', pad=20)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# Analysis:- No. of goal per country for team 1
# Note: You can remove vertical black lines by passing ci parameter. ci=None

# %% [markdown]
# Analysing Team 2 Info

# %%
team2=[x for x in df.columns if "team2" in x]
team2_df = df[team2].copy()
team2_df
# Out:
#              team2  possession team2  number of goals team2  total attempts team2  conceded team2  goal inside the penalty area team2  goal outside the penalty area team2  assists team2  on target attempts team2  off target attempts team2  attempts inside the penalty area  team2  attempts outside the penalty area  team2  left channel team2  left inside channel team2  central channel team2  right inside channel team2  right channel team2  total offers to receive team2  inbehind offers to receive team2  inbetween offers to receive team2  infront offers to receive team2  receptions between midfield and defensive lines team2  attempted line breaks team2  completed line breaks team2  attempted defensive line breaks team2  completed defensive line breaks team2  yellow cards team2  red cards team2  fouls against team2  offsides team2  passes team2  passes completed team2  switches of play completed team2  corners team2  free kicks team2  penalties scored team2  goal preventions team2  \
# ...

# %%
plt.figure(figsize=[10,5])
sns.barplot(x=team2_df["team2"], y=team2_df["number of goals team2"]).set_title("Number Of Goals By Team2", fontsize=20, color='Blue', pad=20)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# Analysis:- No. of goal done by team 2 per country

# %%
team2_df.count()
# Out:
# team2                                                    64
# possession team2                                         64
# number of goals team2                                    64
# total attempts team2                                     64
# conceded team2                                           64
# goal inside the penalty area team2                       64
# goal outside the penalty area team2                      64
# assists team2                                            64
# on target attempts team2                                 64
# off target attempts team2                                64
# attempts inside the penalty area  team2                  64
# attempts outside the penalty area  team2                 64
# left channel team2                                       64
# left inside channel team2                                64
# central channel team2                                    64
# right inside channel team2                               64
# ...

# %%
plt.figure(figsize=[20,5])

plt.subplot(1,2,1)
team1_df.team1.value_counts(normalize=False).plot.barh(color='firebrick').set_title("Match Count For Team1 Per Country", 
                                                                                            fontsize=20, color='indigo', pad=20)

plt.subplot(1,2,2)
team2_df.team2.value_counts(normalize=False).plot.barh(color='green').set_title("Match Count For Team2 Per Country", 
                                                                                        fontsize=20, color='indigo', pad=20)

plt.show()

# %% [markdown]
# Analysis:- No of match played by each country for both team

# %%
# plt.figure(figsize=[20,10])

# sns.boxenplot(x = df['yellow cards team1'] , y = df['total attempts team1'] , 
#             hue = df['category']).set_title("Yellow Card vs Total Attempts For Team1  " , fontsize=30, color='Green', pad=20)
# plt.xlabel("yellow cards count", fontdict={'fontsize': 25, 'fontweight' : 5, 'color' : 'Brown'})
# plt.ylabel("total attempts", fontdict={'fontsize': 25, 'fontweight' : 5, 'color' : 'Brown'})

# plt.show()
sns.set(font_scale=1.3)
sns.lineplot(
    y='total attempts team1', 
    x='yellow cards team1', 
    data=df)
plt.xlabel(
    'Yellow Card')
plt.ylabel(
    'Total Attempts')
# Out:
# Text(0, 0.5, 'Total Attempts')

# %% [markdown]
# #Yellow card Vs total attempts team1
# Analysis:- Above plot shows yellow card hold by country vs total attempts for team1 per category.
# Attempts count: Maximun attempts are near 24 and min attempts near 1
# Yellow card count:- maximum yellow card count is 8 and min is 0

# %%
#Yellow card Vs total attempts team2

plt.figure(figsize=[20,10])

sns.boxenplot(x = df['yellow cards team2'] , y = df['total attempts team2'] , 
            hue = df['category']).set_title("Yellow Card vs Total Attempts For Team2  " , fontsize=30, color='Green', pad=20)
plt.xlabel("yellow cards count", fontdict={'fontsize': 25, 'fontweight' : 5, 'color' : 'Brown'})
plt.ylabel("total attempts", fontdict={'fontsize': 25, 'fontweight' : 5, 'color' : 'Brown'})

plt.show()

# %% [markdown]
# #Yellow card Vs total attempts team1
# Analysis:- Above plot shows yellow card hold by country vs total attempts for team2 per category.
# Attempts count: Maximun attempts are near 35 and min attempts are 0
# Yellow card count:- maximum yellow card count is 8 and min is 0

# %% [markdown]
# Group A Analysis

# %%
GroupA=df.loc[df.category == 'Group A']
GroupA
# Out:
#           team1        team2  possession team1  possession team2 possession in contest  number of goals team1  number of goals team2       date     hour category  total attempts team1  total attempts team2  conceded team1  conceded team2  goal inside the penalty area team1  goal inside the penalty area team2  goal outside the penalty area team1  goal outside the penalty area team2  assists team1  assists team2  on target attempts team1  on target attempts team2  off target attempts team1  off target attempts team2  attempts inside the penalty area team1  attempts inside the penalty area  team2  attempts outside the penalty area  team1  attempts outside the penalty area  team2  left channel team1  left channel team2  left inside channel team1  left inside channel team2  central channel team1  central channel team2  right inside channel team1  right inside channel team2  right channel team1  right channel team2  total offers to receive team1  total offers to receive team2  \
# ...

# %%
plt.figure(figsize=[20,15])

sns.set_style('darkgrid')

plt.subplot(2,2,1)
sns.boxplot(GroupA['number of goals team1']).set_title("number of goals team1", fontsize=20, color='Green', pad=20)


plt.subplot(2,2,2)
sns.boxplot(GroupA['number of goals team2']).set_title("number of goals team2", fontsize=20, color='Blue', pad=20)

plt.subplot(2,2,3)
# sns.distplot(GroupA['yellow cards team1'], color='g')
sns.boxplot(GroupA['yellow cards team1']).set_title("yellow cards team1", fontsize=20, color='Green', pad=20)

plt.subplot(2,2,4)
# sns.distplot(GroupA['EXT_SOURCE_3'], color='g')
sns.boxplot(GroupA['yellow cards team2']).set_title("yellow cards team2", fontsize=20, color='Blue', pad=20)

plt.show()

# %% [markdown]
# Analysis:-  Above plot shows the no of goals for team 1 vs team2 and yellow card count team1 vs team2 for GroupA category
# *No of Goals:- Team 2 scored high goals than team1. Max goal done by team 1 is 1 and no of goal done by team 2 is 3
# *There are 2 outliers in team 2 i.e., no of goals of team 2 is 0 sometimes and yellow card count is 3 for some country
#
# We can check:-
# 1. if and how data is skewed
# 2. how data is grouped
# 3. how outliers are spread

# %% [markdown]
# Handling outliers:-

# %%
np.where(GroupA['number of goals team2']==0)
#Either drop directly/ use IQR(Inter quartile range to detect and remove outlier)
# Out:
# (array([4], dtype=int64),)

# %%
plt.figure(figsize=[20,15])

sns.set_style('darkgrid')

plt.subplot(2,2,1)
sns.distplot(GroupA['left channel team1'], color='g')

plt.subplot(2,2,2)
sns.distplot(GroupA['left channel team2'], color='g')

plt.subplot(2,2,3)
sns.distplot(GroupA['right channel team1'], color='g')

plt.subplot(2,2,4)
sns.distplot(GroupA['right channel team2'], color='g')

plt.show()

# %% [markdown]
# Analysis: Above plot shows the points lies between left channel and right channel for team1 vs team2
# *Used histogram to present values which all gives information about Asymmetry.
# * Right channel team2 is almost having normal distribution as compare to team1
# * Distribution with a longer right tail are right-skewed distibution or positively skewed distribution[As shown in Above plots]

# %%
left_team1=GroupA['left channel team1'].skew()
left_team2=GroupA['left channel team2'].skew()
right_team1=GroupA['right channel team1'].skew()
right_team2=GroupA['right channel team2'].skew()
left_team1,left_team2,right_team1,right_team2
# Out:
# (1.3116965399626033,
#  1.9985938155531986,
#  1.2602528330781453,
#  0.6833387222122393)

# %% [markdown]
# To get clear value of skewness, we can use .skew()

# %%
left_team1=np.log(GroupA['left channel team1']).skew()
left_team2=np.log(GroupA['left channel team2']).skew()
right_team1=np.log(GroupA['right channel team1']).skew()
right_team2=np.log(GroupA['right channel team2']).skew()
left_team1,left_team2,right_team1,right_team2
# Out:
# (0.4223193039443369,
#  1.5004056425337542,
#  0.1757219824304706,
#  0.22131271541671152)

# %%
plt.figure(figsize=[20,15])

sns.set_style('darkgrid')

plt.subplot(2,2,1)
# sns.boxplot(GroupA['left channel team1']).set_title("left channel team1", fontsize=20, color='Green', pad=20)
sns.distplot(np.log(GroupA['left channel team1']), color='g')

plt.subplot(2,2,2)
# sns.boxplot(GroupA['left channel team2']).set_title("left channel team2", fontsize=20, color='Red', pad=20)
sns.distplot(np.log(GroupA['left channel team2']), color='g')

plt.subplot(2,2,3)
sns.distplot(np.log(GroupA['right channel team1']), color='g')

plt.subplot(2,2,4)
sns.distplot(np.log(GroupA['right channel team2']), color='g')

plt.show()

# %% [markdown]
# Above plot is quite good then previous one. There are many methods to reduce skewness in which some of them are-
# 1. Log Transform
# 2. Square Root Transform
# 3. Box-Cox Transform

# %%
#Goal Prevention
import plotly.express as px
import plotly.graph_objs as go

# %%
go.Figure(data=[go.Pie(labels=GroupA['goal preventions team1'].value_counts(normalize=True).index,
                       values=GroupA['goal preventions team1'].value_counts(normalize=True).values, hole=.6,
                       title = 'goal preventions team1')])

# %% [markdown]
# Analysis: Goal prevention points scored by team1

# %%
go.Figure(data=[go.Pie(labels=GroupA['goal preventions team2'].value_counts(normalize=True).index,
                       values=GroupA['goal preventions team2'].value_counts(normalize=True).values, hole=.6,
                       title = 'goal preventions team2')])

# %% [markdown]
# Analysis: Goal prevention points scored by team2

# %%
plt.figure(figsize=[12,12])

f=sns.heatmap(df[['number of goals team1' , 'total attempts team1' , 'goal inside the penalty area team1' , 'goal outside the penalty area team1' , 'on target attempts team1' ,
                          'off target attempts team1' , 'fouls against team1' , 'offsides team1']].corr(),
              cmap = "PRGn" , annot=True).set_title('Correlation between variables', fontsize = 25, color='NAvy')

plt.show()

# %% [markdown]
# Analysis: Above graph shows the correlation between these variables for team1-number of goals team1' , 'total attempts team1' , 'goal inside the penalty area team1' , 'goal outside the penalty area team1' , 'on target attempts team1' ,'off target attempts team1' , 'fouls against team1' , 'offsides team1'
# * some values are in negative

# %%
#Team2
plt.figure(figsize=[12,12])

f=sns.heatmap(df[['number of goals team2' , 'total attempts team2' , 'goal inside the penalty area team2' , 'goal outside the penalty area team2' , 'on target attempts team2' ,
                          'off target attempts team2' , 'fouls against team2' , 'offsides team2']].corr(),
              cmap = "PRGn" , annot=True).set_title('Correlation between variables', fontsize = 25, color='NAvy')

plt.show()

# %% [markdown]
# Analysis: Above graph shows the correlation between these variables for team1-number of goals team2' , 'total attempts team2' , 'goal inside the penalty area team2' , 'goal outside the penalty area team2' , 'on target attempts team2' ,'off target attempts team2' , 'fouls against team2' , 'offsides team2'
# it shows strong correlation between variables

# %%
#pair plot
f = sns.pairplot(df[['number of goals team1','total attempts team1','goal inside the penalty area team1','goal outside the penalty area team1']] , height = 3)
f.fig.suptitle('No of goals vs total attempts vs goal inside and outside penalty team1 \n\n\n\n\n\n\n', fontsize = 25, color='Green')

plt.show()

# %% [markdown]
# Analysis:- Above plot shows relationship between no of goal, total attemps, goal inside penalty area and goal outside penalty area for team1

# %%
#pair plot
f = sns.pairplot(df[['number of goals team2','total attempts team2','goal inside the penalty area team2','goal outside the penalty area team2']] , height = 3)
f.fig.suptitle('No of goals vs total attempts vs goal inside and outside penalty team2 \n\n\n\n\n\n\n', fontsize = 25, color='Green')

plt.show()

# %% [markdown]
# Analysis:- Above plot shows relationship between no of goal, total attemps, goal inside penalty area and goal outside penalty area for team2

# %%
max_values=df.groupby(['category'], sort=True).max()
max_values
# Out:
#                                  team1          team2  possession team1  possession team2 possession in contest  number of goals team1  number of goals team2       date     hour  total attempts team1  total attempts team2  conceded team1  conceded team2  goal inside the penalty area team1  goal inside the penalty area team2  goal outside the penalty area team1  goal outside the penalty area team2  assists team1  assists team2  on target attempts team1  on target attempts team2  off target attempts team1  off target attempts team2  attempts inside the penalty area team1  attempts inside the penalty area  team2  attempts outside the penalty area  team1  attempts outside the penalty area  team2  left channel team1  left channel team2  left inside channel team1  left inside channel team2  central channel team1  central channel team2  right inside channel team1  right inside channel team2  right channel team1  right channel team2  total offers to receive team1  \
# category
# ...

# %%
sns.lineplot(x="category",y="team2",data=max_values,c = 'Green',linewidth = '3')
sns.lineplot(x="category",y="team1",data=max_values,c = 'Yellow',linewidth = '3')
plt.xticks(rotation = 90)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Above plot shows team wise top performing country per category

# %%
min_values=df.groupby(['category'], sort=True).min()
min_values
# Out:
#                                team1       team2  possession team1  possession team2 possession in contest  number of goals team1  number of goals team2       date     hour  total attempts team1  total attempts team2  conceded team1  conceded team2  goal inside the penalty area team1  goal inside the penalty area team2  goal outside the penalty area team1  goal outside the penalty area team2  assists team1  assists team2  on target attempts team1  on target attempts team2  off target attempts team1  off target attempts team2  attempts inside the penalty area team1  attempts inside the penalty area  team2  attempts outside the penalty area  team1  attempts outside the penalty area  team2  left channel team1  left channel team2  left inside channel team1  left inside channel team2  central channel team1  central channel team2  right inside channel team1  right inside channel team2  right channel team1  right channel team2  total offers to receive team1  total offers to receive team2  \
# ...

# %% [markdown]
# Above plot shows team wise less performing country per category

# %%
sns.lineplot(x="category",y="team2",data=min_values,c = 'violet',linewidth = '3')
sns.lineplot(x="category",y="team1",data=min_values,c = 'blue',linewidth = '3')
plt.xticks(rotation = 90)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Analysing possession in contest of all country played in FIFA Match
# What is possession in contest:- Matrics designed to measure the proportion of match when neither side is in control of the ball

# %%
# df['possession in contest'].min()
pss=df['possession in contest'].apply(lambda x: x.replace('%',''))
df['possession in contest']=pss
# df.head(2)
plt.figure(figsize=[20,5])

plt.subplot(1,2,1)
sns.boxplot(df['possession in contest']).set_title("possession in contest - BOX PLOT", fontsize=20, color='indigo', pad=20)

plt.subplot(1,2,2)
sns.distplot(df['possession in contest'], color='green').set_title("possession in contest - DISTRIBUTION",
                                                                      fontsize=20, color='indigo', pad=20)

plt.show()

# %% [markdown]
# Analysis:- In Above plot all the values lies between 8-18. There is only one outlier means which does not lies in this range

# %%
#Quarter-final
quarter_final=df.loc[df.category == 'Quarter-final']
quarter_final
# Out:
#           team1      team2  possession team1  possession team2 possession in contest  number of goals team1  number of goals team2       date     hour       category  total attempts team1  total attempts team2  conceded team1  conceded team2  goal inside the penalty area team1  goal inside the penalty area team2  goal outside the penalty area team1  goal outside the penalty area team2  assists team1  assists team2  on target attempts team1  on target attempts team2  off target attempts team1  off target attempts team2  attempts inside the penalty area team1  attempts inside the penalty area  team2  attempts outside the penalty area  team1  attempts outside the penalty area  team2  left channel team1  left channel team2  left inside channel team1  left inside channel team2  central channel team1  central channel team2  right inside channel team1  right inside channel team2  right channel team1  right channel team2  total offers to receive team1  total offers to receive team2  \
# ...

# %%
sns.lineplot(x="team1",y="team2",data=quarter_final,c = 'Green',linewidth = '3',hue='date')
plt.xticks(rotation = 90)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Anaysis:- Above plot shows total team those are qualified for quarter-final.And shows which country played against which country on which date

# %%
sns.barplot(x="number of goals team1",y="total attempts team1",data=quarter_final,width = 0.5,hue='team1').set_title("No Of Goals Vs Total Attempts")
plt.xticks(rotation = 90)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Analysis:- Above plot shows the no of of goal done per country vs total attempts for team1
# *Maximum attempt count is 14 done by England with 1 goal
# *Minimun attempt count is 5 done by Netherlands with 2 goal

# %%
sns.barplot(x="number of goals team2",y="total attempts team2",data=quarter_final,width = 0.5,hue='team1').set_title("No Of Goals Vs Total Attempts")
plt.xticks(rotation = 90)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Analysis:- Above plot shows the no of of goal done per country vs total attempts for team2
# *Maximum attempt count is 20 done by Crotia with 1 goal
# *Minimun attempt count is 9 done by England with 2 goal

# %%
#pair plot
f = sns.pairplot(quarter_final[['number of goals team1','total attempts team1','goal inside the penalty area team1','goal outside the penalty area team1']] , height = 3)
f.fig.suptitle('No of goals vs total attempts vs goal inside and outside penalty team1 \n\n\n\n\n\n\n', fontsize = 25, color='Green')

plt.show()

# %%
f = sns.pairplot(quarter_final[['number of goals team2','total attempts team2','goal inside the penalty area team2','goal outside the penalty area team2']] , height = 3)
f.fig.suptitle('No of goals vs total attempts vs goal inside and outside penalty team1 \n\n\n\n\n\n\n', fontsize = 25, color='Green')

plt.show()

# %%
plt.figure(figsize=[15,5])

plt.subplot(1,2,1)
quarter_final['goal inside the penalty area team1'].value_counts(normalize=True).plot.barh(color='firebrick').set_title("Goal Inside Penalty Team1 %",
                                                                                               fontsize=20, color='indigo', pad=20)

plt.subplot(1,2,2)
quarter_final['goal inside the penalty area team2'].value_counts(normalize=True).plot.barh(color='green').set_title("Goal Inside Penalty Team2 %",
                                                                                           fontsize=20, color='indigo', pad=20)


plt.show()

# %% [markdown]
# Analysis:- Above plot show the goal inside the penalty area for team 1 and team 2
# *max goal count % is 1 for both team 1 and team 2

# %%
plt.figure(figsize=[15,5])
plt.subplot(1,2,1)
quarter_final['goal outside the penalty area team1'].value_counts(normalize=True).plot.barh(color='Blue').set_title("Goal Outside Penalty Team1 %",
                                                                                               fontsize=20, color='Red', pad=20)

plt.subplot(1,2,2)
quarter_final['goal outside the penalty area team2'].value_counts(normalize=True).plot.barh(color='Orange').set_title("Goal Outside Penalty Team2 %",
                                                                                           fontsize=20, color='Red', pad=20)
plt.show()

# %% [markdown]
# Analysis:- Above plot show the goal outside the penalty area for team 1 and team 2
# *max goal count % is 0 for both team 1 and team 2

# %%
#Semi Final Match Analysis
semi_category=df.loc[df.category == 'Semi-final']
semi_category
# Out:
#         team1    team2  possession team1  possession team2 possession in contest  number of goals team1  number of goals team2       date     hour    category  total attempts team1  total attempts team2  conceded team1  conceded team2  goal inside the penalty area team1  goal inside the penalty area team2  goal outside the penalty area team1  goal outside the penalty area team2  assists team1  assists team2  on target attempts team1  on target attempts team2  off target attempts team1  off target attempts team2  attempts inside the penalty area team1  attempts inside the penalty area  team2  attempts outside the penalty area  team1  attempts outside the penalty area  team2  left channel team1  left channel team2  left inside channel team1  left inside channel team2  central channel team1  central channel team2  right inside channel team1  right inside channel team2  right channel team1  right channel team2  total offers to receive team1  total offers to receive team2  \
# ...

# %%
sns.barplot(x="number of goals team1",y="total attempts team1",data=semi_category,width = 0.5,hue='team1').set_title("No Of Goals Vs Total Attempts")
plt.xticks(rotation = 90)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Analysis:- Above plot shows the no of goals vs total attempts for team 1

# %%
#country wise goal and total attempts for team2
sns.barplot(x="number of goals team2",y="total attempts team2",data=semi_category,width = 0.5,hue='team2').set_title("No Of Goals Vs Total Attempts")
plt.xticks(rotation = 90)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Analysis:- Above plot shows the no of goals vs total attempts for team 2

# %%
# Match Analysis
final=df.loc[df.category == 'Final']
final
# Out:
#         team1   team2  possession team1  possession team2 possession in contest  number of goals team1  number of goals team2       date     hour category  total attempts team1  total attempts team2  conceded team1  conceded team2  goal inside the penalty area team1  goal inside the penalty area team2  goal outside the penalty area team1  goal outside the penalty area team2  assists team1  assists team2  on target attempts team1  on target attempts team2  off target attempts team1  off target attempts team2  attempts inside the penalty area team1  attempts inside the penalty area  team2  attempts outside the penalty area  team1  attempts outside the penalty area  team2  left channel team1  left channel team2  left inside channel team1  left inside channel team2  central channel team1  central channel team2  right inside channel team1  right inside channel team2  right channel team1  right channel team2  total offers to receive team1  total offers to receive team2  \
# ...

# %%
max_duration=df.groupby(['hour'], sort=True).max()
max_duration
# Out:
#            team1        team2  possession team1  possession team2 possession in contest  number of goals team1  number of goals team2       date     category  total attempts team1  total attempts team2  conceded team1  conceded team2  goal inside the penalty area team1  goal inside the penalty area team2  goal outside the penalty area team1  goal outside the penalty area team2  assists team1  assists team2  on target attempts team1  on target attempts team2  off target attempts team1  off target attempts team2  attempts inside the penalty area team1  attempts inside the penalty area  team2  attempts outside the penalty area  team1  attempts outside the penalty area  team2  left channel team1  left channel team2  left inside channel team1  left inside channel team2  central channel team1  central channel team2  right inside channel team1  right inside channel team2  right channel team1  right channel team2  total offers to receive team1  total offers to receive team2  \
# hour
# ...

# %%
sns.lineplot(x="hour",y="category",data=max_duration,c = 'Red',linewidth = '3')
plt.xticks(rotation = 90)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Analysis: Above plot shows the group whose match played duration is maximum among all. Semi Final match played max duration.

# %%
min_duration=df.groupby(['hour'], sort=True).min()
min_duration.head(1)
# Out:
#              team1      team2  possession team1  possession team2 possession in contest  number of goals team1  number of goals team2       date category  total attempts team1  total attempts team2  conceded team1  conceded team2  goal inside the penalty area team1  goal inside the penalty area team2  goal outside the penalty area team1  goal outside the penalty area team2  assists team1  assists team2  on target attempts team1  on target attempts team2  off target attempts team1  off target attempts team2  attempts inside the penalty area team1  attempts inside the penalty area  team2  attempts outside the penalty area  team1  attempts outside the penalty area  team2  left channel team1  left channel team2  left inside channel team1  left inside channel team2  central channel team1  central channel team2  right inside channel team1  right inside channel team2  right channel team1  right channel team2  total offers to receive team1  total offers to receive team2  \
# hour
# ...

# %% [markdown]
# Final Conclusion:
#
# The fifa match dataset were analyzed, cleaned and inferences/correlations were drawn. We have thoroughly observed these datasets and here are our observations and comments about the same:
# -These are 13 category means 13 groups played FIFA
# -Group A,B,C,D,E,F,G,H contains 12 team total, 6 each
# -Country ARGENTINA and FRANCE qualified for finals. possession in contest for finals are quite good, its 14%.
# -Free kick, total attempts by team 2 is more than team 1
# -No of goals by team 1 is more than team 2
# -Goal prevention count for team1 is more than team2
# -Max count of red card team 1 have is 1 and team 2 is 0.
# -Free kick points of team 1 is more than team 2
# -The match whose duration is very less have zero goals from both team1 & team2, comes under Group B.
# -All cloumns present in datasets are mostly independent column. Winning or selection depends on these independent column. Hence for winning, goal prevention, no of goal, free kick etc. columns are important.
